# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests
from requests.exceptions import SSLError
import pickle

# customisations - ensure tables show all columns
pd.set_option("max_columns", 100)

# %%
def get_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 10 seconds...')
        time.sleep(10)
        print('Retrying.')
        return get_request(url, parameters)

# %%
url = "https://steamspy.com/api.php"
parameters = {"request": "all"}

# request 'all' from steam spy and parse into dataframe
json_data = get_request(url, parameters=parameters)
steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

# generate sorted app_list from steamspy data
app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# export disabled to keep consistency across download sessions
app_list.to_csv('app_list.csv', index=False)

# instead read from stored csv
app_list = pd.read_csv('app_list.csv')

# display first few rows
app_list.head()
# Out:
#    appid                                     name
# 0  33760            The Search for Amelia Earhart
# 1  34274                         Ecco the Dolphin
# 2  34275                              Gain Ground
# 3  34277  Shinobi III: Return of the Ninja Master
# 4  34311                            Kid Chameleon

# %%
len(app_list)
# Out:
# 1000

# %%
def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data

# %%
def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=50, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()


def skip_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    new_index = index + 1
            
    with open(rel_path, 'w') as f:
        print(new_index, file=f)

# %%
def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data


# # Set file parameters
# download_path = '../data/download'
# steam_app_data = 'steam_app_data.csv'
# steam_index = 'steam_index.txt'

# steam_columns = [
#     'name', 'steam_appid',
   
#     'pc_requirements',
    
   
#    'genres'
# ]


# # Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
# reset_index(download_path, steam_index)

# # Retrieve last index downloaded from file
# index = get_index(download_path, steam_index)

# # Wipe or create data file and write headers if index is 0
# prepare_data_file(download_path, steam_app_data, index, steam_columns)

# # Set end and chunksize for demonstration - remove to run through entire app list
# process_batches(
#     parser=parse_steam_request,
#     app_list=app_list,
#     download_path=download_path,
#     data_filename=steam_app_data,
#     index_filename=steam_index,
#     columns=steam_columns,
#     begin=index,
#     end=10,
#     batchsize=5
# )

# %%
def parse_steamspy_request(appid, name):
    """Parser to handle SteamSpy API data."""
    url = "https://steamspy.com/api.php"
    parameters = {"request": "appdetails", "appid": appid}
    
    json_data = get_request(url, parameters)
    return json_data

# set files and columns
download_path = '../'
steamspy_data = 'steamspy_data.csv'
steamspy_index = 'steamspy_index.txt'

steamspy_columns = [
    'appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
    'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
    'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
    'languages', 'genre', 'ccu', 'tags'
]

# reset_index(download_path, steamspy_index)
index = get_index(download_path, steamspy_index)

# Wipe data file if index is 0
prepare_data_file(download_path, steamspy_data, index, steamspy_columns)

process_batches(
    parser=parse_steamspy_request,
    app_list=app_list,
    download_path=download_path, 
    data_filename=steamspy_data,
    index_filename=steamspy_index,
    columns=steamspy_columns,
    begin=index,
    end=-1,
    batchsize=50,
    pause=0.3
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4e8eb779e5c8> in <module>
#      25 prepare_data_file(download_path, steamspy_data, index, steamspy_columns)
#      26
# ---> 27 process_batches(
#      28     parser=parse_steamspy_request,
#      29     app_list=app_list,
#
# NameError: name 'process_batches' is not defined

# %%
len(app_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9fda8679f998> in <module>
# ----> 1 len(app_list)
#
# NameError: name 'app_list' is not defined

# %%
app_list[:-50]

# %%
pd.read_csv('../steamspy_data.csv').head(50)
# Out:
# Empty DataFrame
# Columns: [appid, name, developer, publisher, score_rank, positive, negative, userscore, owners, average_forever, average_2weeks, median_forever, median_2weeks, price, initialprice, discount, languages, genre, ccu, tags]
# Index: []

# %%
def process_library_batches(parser, steamid_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=50, pause=1):
    """Process library data in batches, writing directly to file.
    
    parser : custom function to format request
    steamid_list : dataframe of steamids
    download_path : path to store data
    data_filename : filename to save library data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of steamid_list)
    batchsize : number of libraries to write in each batch (default 50)
    pause : time to wait after each api request (default 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all steamids in steamid_list
    if end == -1:
        end = len(steamid_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    libraries_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        library_data = get_library_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing library data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(library_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        libraries_written += len(library_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} libraries written'.format(libraries_written))

# %%
def get_library_data(start, stop, parser, pause):
    """Return list of library data generated from parser.
    
    parser : function to handle request
    """
    library_data = []
    index = start
    
    # iterate through each row of steamid_list, confined by start and stop
    for steamid in steamid_list[start:stop]:
        print('Current index: {}'.format(index), end='\r')
        index += 1
        
        # retrieve library data for a row, handled by supplied parser, and append to list
        data = parser(steamid)
        library_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return library_data

# %%
def parse_steam_library(steamid):
    """Parser to handle library data."""
    url = "https://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/"
    parameters = {'include_appinfo': True, 'steamid': steamid}
    
    json_data = get_library_request(url, parameters)
    
    if json_data['response']:
        return {'steamid':steamid, 'library':[{'appid': game['appid'], 'name': game['name'], 'hours': game['playtime_forever']} for game in json_data['response']['games']]}
    else:
        return {'steamid':steamid, 'library':'hidden'}

# %%
def get_library_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(
        url,
        {
            **parameters,
            **{
                'key': '9C34DB5DC9F6FB662853AC6217BC048F',
                'format': 'json'
            }
        }
    )
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_library_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 5 seconds...')
        time.sleep(5)
        print('Retrying.')
#         wait_counter += 1
#         if wait_counter == 2:
#             wait_counter = 0
#             return please_just_work()
#         return get_library_request(url, parameters)
        return please_just_work()

# %%
with open('steamid_list.pickle', 'rb') as handle:
   steamid_list = pickle.load(handle)

# %%
steamid_list
# Out:
# [76561198219067393,
#  76561198148157441,
#  76561198993539076,
#  76561198247182340,
#  76561198278705159,
#  76561198306000904,
#  76561199041871881,
#  76561198398210058,
#  76561198313209867,
#  76561198170079242,
#  76561199187853325,
#  76561198424457231,
#  76561199073034256,
#  76561198088650778,
#  76561198128726044,
#  76561198886682654,
#  76561198311899167,
#  76561199160819745,
#  76561199085551652,
#  76561198401257513,
#  76561199063236653,
#  76561198809874484,
#  76561199122907193,
#  76561197992706107,
#  76561198836187202,
#  76561198372618308,
#  76561198063386696,
#  76561198998093897,
#  76561198147928140,
#  76561199100035151,
#  76561199217773174,
#  76561198408436344,
#  76561197989825145,
#  76561199026244217,
#  76561198125746811,
#  76561198439893627,
#  76561198840416895,
#  76561198350469762,
#  935709837957,
#  76561199013563023,
#  76561198320126608,
#  76561199131036308,
#  76561198064798363,
#  76561198123780766,
#  76561198340508320,
#  76561198344145569,
#  76561199177075362,
#  76561198995770020,
#  76561198029703845,
#  76561198071319210,
#  76561198968638129,
#  76561199122549427,
#  76561199011170996,
#  76561198135085749,
#  76561199137524403,
#  76561198049692343,
#  218434235,
#  76561198353779387,
#  76561199066122941,
#  76561198809713344,
#  76561198056639169,
#  76561199014480581,
#  76561199064189644,
#  76561198277954253,
#  1374628481747,
#  76561199182416597,
#  76561199167769302,
#  76561198368131803,
#  76561198119684830,
#  ...]

# %%
def please_just_work():
    # set files and columns
    download_path = '../data'
    library_data = 'library_data.csv'
    library_index = 'library_index.txt'
    api_key = '9C34DB5DC9F6FB662853AC6217BC048F'

    library_columns = [
        'steamid', 'library'
    ]

    # # Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
    skip_index(download_path, library_index)

    # reset_index(download_path, library_index)

    index = get_index(download_path, library_index)

    # Wipe data file if index is 0
    prepare_data_file(download_path, library_data, index, library_columns)

    process_library_batches(
        parser=parse_steam_library,
        steamid_list=steamid_list,
        download_path=download_path, 
        data_filename=library_data,
        index_filename=library_index,
        columns=library_columns,
        begin=index,
        end=-1,
        batchsize=5,
        pause=.4
    )
please_just_work()
# Out:
# Starting at index 54224:
#
# Exported lines 54224-54228 to library_data.csv. Batch 0 time: 0:00:06 (avg: 0:00:06, remaining: 1:42:42)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54230:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54231:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54232:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54233:
#
# Exported lines 54233-54237 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:27:16)
# Exported lines 54238-54242 to library_data.csv. Batch 1 time: 0:00:04 (avg: 0:00:05, remaining: 1:24:13)
# Exported lines 54243-54247 to library_data.csv. Batch 2 time: 0:00:04 (avg: 0:00:04, remaining: 1:22:41)
# Exported lines 54248-54252 to library_data.csv. Batch 3 time: 0:00:04 (avg: 0:00:04, remaining: 1:22:21)
# Exported lines 54253-54257 to library_data.csv. Batch 4 time: 0:00:04 (avg: 0:00:04, remaining: 1:22:05)
# Exported lines 54258-54262 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:04, remaining: 1:22:27)
# Exported lines 54263-54267 to library_data.csv. Batch 6 time: 0:00:04 (avg: 0:00:04, remaining: 1:22:16)
# Exported lines 54268-54272 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:29)
# Exported lines 54273-54277 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:25)
# Exported lines 54278-54282 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:33)
# Exported lines 54283-54287 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:24:08)
# Exported lines 54288-54292 to library_data.csv. Batch 11 time: 0:00:06 (avg: 0:00:05, remaining: 1:25:32)
# Exported lines 54293-54297 to library_data.csv. Batch 12 time: 0:00:06 (avg: 0:00:05, remaining: 1:27:11)
# Exported lines 54298-54302 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:26:57)
# Exported lines 54303-54307 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:26:46)
# Exported lines 54308-54312 to library_data.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 1:26:43)
# Exported lines 54313-54317 to library_data.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 1:26:29)
# Exported lines 54318-54322 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:26:13)
# Exported lines 54323-54327 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:26:02)
# Exported lines 54328-54332 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:59)
# Exported lines 54333-54337 to library_data.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:57)
# Exported lines 54338-54342 to library_data.csv. Batch 21 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:47)
# Exported lines 54343-54347 to library_data.csv. Batch 22 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:34)
# Exported lines 54348-54352 to library_data.csv. Batch 23 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:33)
# Exported lines 54353-54357 to library_data.csv. Batch 24 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:25)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54359:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54360:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54361:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54362:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54363:
#
# Exported lines 54363-54367 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:28:14)
# Exported lines 54368-54372 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:27:02)
# Exported lines 54373-54377 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:26:28)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54379:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54380:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54381:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54382:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54383:
#
# Exported lines 54383-54387 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:24:07)
# Exported lines 54388-54392 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:25)
# Exported lines 54393-54397 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:11)
# Exported lines 54398-54402 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:39)
# Exported lines 54403-54407 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:34)
# Exported lines 54408-54412 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:37)
# Exported lines 54413-54417 to library_data.csv. Batch 6 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:26)
# Exported lines 54418-54422 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:19)
# Exported lines 54423-54427 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:26)
# Exported lines 54428-54432 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:17)
# Exported lines 54433-54437 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:04)
# Exported lines 54438-54442 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:59)
# Exported lines 54443-54447 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:53)
# Exported lines 54448-54452 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:49)
# Exported lines 54453-54457 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:47)
# Exported lines 54458-54462 to library_data.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:35)
# Exported lines 54463-54467 to library_data.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:30)
# Exported lines 54468-54472 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:26)
# Exported lines 54473-54477 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:18)
# Exported lines 54478-54482 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:19)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54484:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54485:
#
# Exported lines 54485-54489 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:34)
# Exported lines 54490-54494 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:24:38)
# Exported lines 54495-54499 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:24:33)
# Exported lines 54500-54504 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:25:02)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54506:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54507:
#
# Exported lines 54507-54511 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:21:31)
# Exported lines 54512-54516 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:21:55)
# Exported lines 54647-54651 to library_data.csv. Batch 28 time: 0:00:05 (avg: 0:00:05, remaining: 1:21:34)
# Exported lines 54652-54656 to library_data.csv. Batch 29 time: 0:00:08 (avg: 0:00:05, remaining: 1:23:09)
# Exported lines 54657-54661 to library_data.csv. Batch 30 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:17)
# Exported lines 54662-54666 to library_data.csv. Batch 31 time: 0:00:05 (avg: 0:00:05, remaining: 1:23:09)
# Exported lines 54667-54671 to library_data.csv. Batch 32 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:57)
# Exported lines 54672-54676 to library_data.csv. Batch 33 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:50)
# Exported lines 54677-54681 to library_data.csv. Batch 34 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:42)
# Exported lines 54682-54686 to library_data.csv. Batch 35 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:36)
# Exported lines 54687-54691 to library_data.csv. Batch 36 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:26)
# Exported lines 54692-54696 to library_data.csv. Batch 37 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:24)
# Exported lines 54697-54701 to library_data.csv. Batch 38 time: 0:00:05 (avg: 0:00:05, remaining: 1:22:10)
# Exported lines 54702-54706 to library_data.csv. Batch 39 time: 0:00:05 (avg: 0:00:05, remaining: 1:21:57)
# Exported lines 54707-54711 to library_data.csv. Batch 40 time: 0:00:05 (avg: 0:00:05, remaining: 1:21:46)
# Exported lines 54712-54716 to library_data.csv. Batch 41 time: 0:00:05 (avg: 0:00:05, remaining: 1:21:34)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54718:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54719:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54720:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54721:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54722:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54723:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54724:
#
# Exported lines 54724-54728 to library_data.csv. Batch 0 time: 0:00:04 (avg: 0:00:04, remaining: 1:15:26)
# Exported lines 54729-54733 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:46)
# Exported lines 54734-54738 to library_data.csv. Batch 2 time: 0:00:04 (avg: 0:00:04, remaining: 1:15:21)
# Exported lines 54739-54743 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:04, remaining: 1:15:28)
# Exported lines 54744-54748 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:16)
# Exported lines 54749-54753 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:05)
# Exported lines 54754-54758 to library_data.csv. Batch 6 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:56)
# Exported lines 54759-54763 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:08)
# Exported lines 54764-54768 to library_data.csv. Batch 8 time: 0:00:04 (avg: 0:00:05, remaining: 1:16:48)
# Exported lines 54769-54773 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:47)
# Exported lines 54774-54778 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:35)
# Exported lines 54779-54783 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:26)
# Exported lines 54784-54788 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:46)
# Exported lines 54789-54793 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:34)
# Exported lines 54794-54798 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:37)
# Exported lines 54799-54803 to library_data.csv. Batch 15 time: 0:00:04 (avg: 0:00:05, remaining: 1:16:25)
# Exported lines 54804-54808 to library_data.csv. Batch 16 time: 0:00:04 (avg: 0:00:05, remaining: 1:16:13)
# Exported lines 54809-54813 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:14)
# Exported lines 54814-54818 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:12)
# Exported lines 54819-54823 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:02)
# Exported lines 54824-54828 to library_data.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:01)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54830:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54831:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54832:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54833:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54834:
#
# Exported lines 54834-54838 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:20:28)
# Exported lines 54839-54843 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:18:59)
# Exported lines 54844-54848 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:18:36)
# Exported lines 54849-54853 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:18:01)
# Exported lines 54854-54858 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:41)
# Exported lines 54859-54863 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:38)
# Exported lines 54864-54868 to library_data.csv. Batch 6 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:15)
# Exported lines 54869-54873 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:10)
# Exported lines 54874-54878 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:21)
# Exported lines 54879-54883 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:59)
# Exported lines 54884-54888 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:50)
# Exported lines 54889-54893 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:37)
# Exported lines 54894-54898 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:32)
# Exported lines 54899-54903 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:24)
# Exported lines 54904-54908 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:15)
# Exported lines 54909-54913 to library_data.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:12)
# Exported lines 54914-54918 to library_data.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:05)
# Exported lines 54919-54923 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:53)
# Exported lines 54924-54928 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:49)
# Exported lines 54929-54933 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:39)
# Exported lines 54934-54938 to library_data.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:33)
# Exported lines 54939-54943 to library_data.csv. Batch 21 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:33)
# Exported lines 54944-54948 to library_data.csv. Batch 22 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:29)
# Exported lines 54949-54953 to library_data.csv. Batch 23 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:26)
# Exported lines 54954-54958 to library_data.csv. Batch 24 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:19)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54960:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54961:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54962:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54963:
#
# Exported lines 54963-54967 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:15)
# Exported lines 54968-54972 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:47)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 54974:
#
# Exported lines 54974-54978 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:00)
# Exported lines 54979-54983 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:09)
# Exported lines 54984-54988 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:21)
# Exported lines 54989-54993 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:20)
# Exported lines 54994-54998 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:34)
# Exported lines 54999-55003 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:58)
# Exported lines 55004-55008 to library_data.csv. Batch 6 time: 0:00:06 (avg: 0:00:05, remaining: 1:18:09)
# Exported lines 55009-55013 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:30)
# Exported lines 55014-55018 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 1:17:05)
# Exported lines 55019-55023 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:32)
# Exported lines 55024-55028 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:16:06)
# Exported lines 55029-55033 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:55)
# Exported lines 55034-55038 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:41)
# Exported lines 55039-55043 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:31)
# Exported lines 55044-55048 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:11)
# Exported lines 55049-55053 to library_data.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:02)
# Exported lines 55054-55058 to library_data.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 1:15:01)
# Exported lines 55059-55063 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:52)
# Exported lines 55064-55068 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:48)
# Exported lines 55069-55073 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:45)
# Exported lines 55074-55078 to library_data.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:33)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55080:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55081:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55082:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55083:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55084:
#
# Exported lines 55084-55088 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:46)
# Exported lines 55089-55093 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:14:13)
# Exported lines 55094-55098 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:44)
# Exported lines 55099-55103 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:34)
# Exported lines 55104-55108 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:32)
# Exported lines 55109-55113 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:34)
# Exported lines 55114-55118 to library_data.csv. Batch 6 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:22)
# Exported lines 55119-55123 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:25)
# Exported lines 55124-55128 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:23)
# Exported lines 55129-55133 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:35)
# Exported lines 55134-55138 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:29)
# Exported lines 55139-55143 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:21)
# Exported lines 55144-55148 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:02)
# Exported lines 55149-55153 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:04)
# Exported lines 55154-55158 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:12:59)
# Exported lines 55159-55163 to library_data.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 1:12:43)
# Exported lines 55164-55168 to library_data.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:08)
# Exported lines 55169-55173 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:25)
# Exported lines 55174-55178 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:13:13)
# Exported lines 55179-55183 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:12:57)
# Exported lines 55184-55188 to library_data.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 1:12:53)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55190:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55191:
#
# Exported lines 55191-55195 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:11:32)
# Exported lines 55196-55200 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:11:19)
# Exported lines 55201-55205 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:10:46)
# Exported lines 55206-55210 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:11:22)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55212:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55213:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55214:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55215:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55216:
#
# Exported lines 55216-55220 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:09:32)
# Exported lines 55221-55225 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:09:35)
# Exported lines 55226-55230 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:10:25)
# Exported lines 55231-55235 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:10:23)
# Exported lines 55236-55240 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:10:21)
# Exported lines 55241-55245 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 1:10:24)
# Exported lines 55381-55385 to library_data.csv. Batch 33 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:30)
# Exported lines 55386-55390 to library_data.csv. Batch 34 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:28)
# Exported lines 55391-55395 to library_data.csv. Batch 35 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:21)
# Exported lines 55396-55400 to library_data.csv. Batch 36 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:16)
# Exported lines 55401-55405 to library_data.csv. Batch 37 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:20)
# Exported lines 55406-55410 to library_data.csv. Batch 38 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:18)
# Exported lines 55411-55415 to library_data.csv. Batch 39 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:12)
# Exported lines 55416-55420 to library_data.csv. Batch 40 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:07)
# Exported lines 55421-55425 to library_data.csv. Batch 41 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:07)
# Exported lines 55426-55430 to library_data.csv. Batch 42 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:05)
# Exported lines 55431-55435 to library_data.csv. Batch 43 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:01)
# Exported lines 55436-55440 to library_data.csv. Batch 44 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:57)
# Exported lines 55441-55445 to library_data.csv. Batch 45 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:55)
# Exported lines 55446-55450 to library_data.csv. Batch 46 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:01)
# Exported lines 55451-55455 to library_data.csv. Batch 47 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:57)
# Exported lines 55456-55460 to library_data.csv. Batch 48 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:54)
# Exported lines 55461-55465 to library_data.csv. Batch 49 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:51)
# Exported lines 55466-55470 to library_data.csv. Batch 50 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:46)
# Exported lines 55471-55475 to library_data.csv. Batch 51 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:40)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55477:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55478:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55479:
#
# Exported lines 55479-55483 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:43)
# Exported lines 55484-55488 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:09:32)
# Exported lines 55489-55493 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 1:09:43)
# Exported lines 55494-55498 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:39)
# Exported lines 55499-55503 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:08:20)
# Exported lines 55761-55765 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:04:08)
# Exported lines 55766-55770 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 1:04:03)
# Exported lines 55771-55775 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:56)
# Exported lines 55776-55780 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:45)
# Exported lines 55781-55785 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:41)
# Exported lines 55786-55790 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:36)
# Exported lines 55791-55795 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:46)
# Exported lines 55796-55800 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:50)
# Exported lines 55801-55805 to library_data.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:43)
# Exported lines 55806-55810 to library_data.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:46)
# Exported lines 55811-55815 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:36)
# Exported lines 55816-55820 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:28)
# Exported lines 55821-55825 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:20)
# Exported lines 55826-55830 to library_data.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:18)
# Exported lines 55831-55835 to library_data.csv. Batch 21 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:13)
# Exported lines 55836-55840 to library_data.csv. Batch 22 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:10)
# Exported lines 55841-55845 to library_data.csv. Batch 23 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:06)
# Exported lines 55846-55850 to library_data.csv. Batch 24 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:08)
# Exported lines 55851-55855 to library_data.csv. Batch 25 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:59)
# Exported lines 55856-55860 to library_data.csv. Batch 26 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:54)
# Exported lines 55861-55865 to library_data.csv. Batch 27 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:45)
# Exported lines 55866-55870 to library_data.csv. Batch 28 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:45)
# Exported lines 55871-55875 to library_data.csv. Batch 29 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:38)
# Exported lines 55876-55880 to library_data.csv. Batch 30 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:41)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55882:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55883:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55884:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55885:
#
# Exported lines 55885-55889 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:36)
# Exported lines 55890-55894 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:12)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55896:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55897:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55898:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55899:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 55900:
#
# Exported lines 55900-55904 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:16)
# Exported lines 55905-55909 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:10)
# Exported lines 55910-55914 to library_data.csv. Batch 2 time: 0:00:06 (avg: 0:00:05, remaining: 1:06:49)
# Exported lines 55915-55919 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 1:07:05)
# Exported lines 55920-55924 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 1:05:55)
# Exported lines 55925-55929 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 1:04:58)
# Exported lines 55930-55934 to library_data.csv. Batch 6 time: 0:00:05 (avg: 0:00:05, remaining: 1:04:41)
# Exported lines 55935-55939 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 1:04:24)
# Exported lines 55940-55944 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:42)
# Exported lines 55945-55949 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 1:03:09)
# Exported lines 55950-55954 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:51)
# Exported lines 55955-55959 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:22)
# Exported lines 55960-55964 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 1:02:02)
# Exported lines 55965-55969 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:58)
# Exported lines 55970-55974 to library_data.csv. Batch 14 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:49)
# Exported lines 55975-55979 to library_data.csv. Batch 15 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:34)
# Exported lines 55980-55984 to library_data.csv. Batch 16 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:26)
# Exported lines 55985-55989 to library_data.csv. Batch 17 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:15)
# Exported lines 55990-55994 to library_data.csv. Batch 18 time: 0:00:05 (avg: 0:00:05, remaining: 1:01:04)
# Exported lines 55995-55999 to library_data.csv. Batch 19 time: 0:00:05 (avg: 0:00:05, remaining: 1:00:54)
# Exported lines 56000-56004 to library_data.csv. Batch 20 time: 0:00:05 (avg: 0:00:05, remaining: 1:00:45)
# Exported lines 56005-56009 to library_data.csv. Batch 21 time: 0:00:05 (avg: 0:00:05, remaining: 1:00:34)
# Exported lines 56140-56144 to library_data.csv. Batch 48 time: 0:00:05 (avg: 0:00:05, remaining: 0:58:33)
# Exported lines 56145-56149 to library_data.csv. Batch 49 time: 0:00:05 (avg: 0:00:05, remaining: 0:58:25)
# Exported lines 56150-56154 to library_data.csv. Batch 50 time: 0:00:05 (avg: 0:00:05, remaining: 0:58:18)
# Exported lines 56155-56159 to library_data.csv. Batch 51 time: 0:00:05 (avg: 0:00:05, remaining: 0:58:18)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56161:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56162:
#
# Exported lines 56162-56166 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 0:57:39)
# Exported lines 56167-56171 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 0:57:24)
# Exported lines 56172-56176 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 0:57:04)
# Exported lines 56177-56181 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:43)
# Exported lines 56182-56186 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:42)
# Exported lines 56187-56191 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:21)
# Exported lines 56192-56196 to library_data.csv. Batch 6 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:09)
# Exported lines 56197-56201 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:07)
# Exported lines 56202-56206 to library_data.csv. Batch 8 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:04)
# Exported lines 56207-56211 to library_data.csv. Batch 9 time: 0:00:05 (avg: 0:00:05, remaining: 0:55:52)
# Exported lines 56212-56216 to library_data.csv. Batch 10 time: 0:00:05 (avg: 0:00:05, remaining: 0:55:41)
# Exported lines 56217-56221 to library_data.csv. Batch 11 time: 0:00:05 (avg: 0:00:05, remaining: 0:55:36)
# Exported lines 56222-56226 to library_data.csv. Batch 12 time: 0:00:05 (avg: 0:00:05, remaining: 0:55:37)
# Exported lines 56227-56231 to library_data.csv. Batch 13 time: 0:00:05 (avg: 0:00:05, remaining: 0:55:33)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56233:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56234:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56235:
#
# Exported lines 56235-56239 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 0:54:18)
# Exported lines 56240-56244 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 0:55:38)
# Exported lines 56245-56249 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:44)
# Exported lines 56250-56254 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:12)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56256:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56257:
#
# Exported lines 56257-56261 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 0:57:38)
# Exported lines 56262-56266 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:44)
# Exported lines 56267-56271 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:04)
# Exported lines 56272-56276 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 0:56:14)
# Exported lines 56277-56281 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 0:55:36)
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56283:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56284:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56285:
#
# No response, waiting 5 seconds...
# Retrying.
# Starting at index 56286:
#
# Exported lines 56286-56290 to library_data.csv. Batch 0 time: 0:00:05 (avg: 0:00:05, remaining: 0:54:09)
# Exported lines 56291-56295 to library_data.csv. Batch 1 time: 0:00:05 (avg: 0:00:05, remaining: 0:53:45)
# Exported lines 56296-56300 to library_data.csv. Batch 2 time: 0:00:05 (avg: 0:00:05, remaining: 0:53:43)
# Exported lines 56301-56305 to library_data.csv. Batch 3 time: 0:00:05 (avg: 0:00:05, remaining: 0:53:33)
# Exported lines 56306-56310 to library_data.csv. Batch 4 time: 0:00:05 (avg: 0:00:05, remaining: 0:53:29)
# Exported lines 56311-56315 to library_data.csv. Batch 5 time: 0:00:05 (avg: 0:00:05, remaining: 0:53:22)
# Exported lines 56316-56320 to library_data.csv. Batch 6 time: 0:00:05 (avg: 0:00:05, remaining: 0:53:21)
# Exported lines 56321-56325 to library_data.csv. Batch 7 time: 0:00:05 (avg: 0:00:05, remaining: 0:53:21)
# ...
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-38-87c136b5c99b> in get_library_request(url, parameters)
#      47 #             return please_just_work()
#      48 #         return get_library_request(url, parameters)
# ---> 49         return please_just_work()
#
# <ipython-input-48-554f9e8388be> in please_just_work()
#      20     prepare_data_file(download_path, library_data, index, library_columns)
#      21
# ---> 22     process_library_batches(
#      23         parser=parse_steam_library,
#      24         steamid_list=steamid_list,
#
# <ipython-input-7-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-21-21bcd409122e> in get_library_data(start, stop, parser, pause)
#      13
#      14         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 15         data = parser(steamid)
#      16         library_data.append(data)
#      17
#
# <ipython-input-9-9a2b27e58e1e> in parse_steam_library(steamid)
#       6     json_data = get_library_request(url, parameters)
#       7
# ----> 8     if json_data['response']:
#       9         return {'steamid':steamid, 'library':[{'appid': game['appid'], 'name': game['name'], 'hours': game['playtime_forever']} for game in json_data['response']['games']]}
#      10     else:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# !pip install requests --upgrade
# Out:
# Collecting requests
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5; python_version >= "3" in c:\users\chris\appdata\roaming\python\python38\site-packages (from requests) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in c:\users\chris\appdata\roaming\python\python38\site-packages (from requests) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\chris\appdata\roaming\python\python38\site-packages (from requests) (2020.6.20)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.8-py3-none-any.whl (39 kB)
# Installing collected packages: charset-normalizer, requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
# Successfully installed charset-normalizer-2.0.8 requests-2.26.0
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# google-api-core 1.22.2 requires protobuf>=3.12.0, but you'll have protobuf 3.11.2 which is incompatible.

# %%
# reset_index(download_path, library_index)
index = get_index(download_path, library_index)
index
# Out:
# 163

# %%
pd.read_csv('../data/library_data.csv').head()
# Out:
#              steamid                                            library
# 0  76561198219067393  [{'appid': 220, 'name': 'Half-Life 2', 'hours'...
# 1  76561198148157441  [{'appid': 17390, 'name': 'Spore', 'hours': 26...
# 2  76561198993539076                                             hidden
# 3  76561198247182340                                             hidden
# 4  76561198278705159                                             hidden

# %%
library_df = pd.read_csv('../data/library_data.csv')

# %%
library_df.head(50)
# Out:
#               steamid                                            library
# 0   76561198219067393  [{'appid': 220, 'name': 'Half-Life 2', 'hours'...
# 1   76561198148157441  [{'appid': 17390, 'name': 'Spore', 'hours': 26...
# 2   76561198993539076                                             hidden
# 3   76561198247182340                                             hidden
# 4   76561198278705159                                             hidden
# 5   76561198306000904                                             hidden
# 6   76561199041871881                                             hidden
# 7   76561198398210058                                             hidden
# 8   76561198313209867                                             hidden
# 9   76561198170079242  [{'appid': 3830, 'name': 'Psychonauts', 'hours...
# 10  76561199187853325                                             hidden
# 11  76561198424457231                                             hidden
# 12  76561199073034256                                             hidden
# 13  76561198088650778  [{'appid': 4000, 'name': "Garry's Mod", 'hours...
# 14  76561198128726044                                             hidden
# 15  76561198886682654  [{'appid': 4000, 'name': "Garry's Mod", 'hours...
# 16  76561198311899167  [{'appid': 10, 'name': 'Counter-Strike', 'hour...
# 17  76561199160819745                                             hidden
# 18  76561199085551652  [{'appid': 4000, 'name': "Garry's Mod", 'hours...
# 19  76561198401257513                                             hidden
# 20  76561199063236653  [{'appid': 500, 'name': 'Left 4 Dead', 'hours'...
# 21  76561198809874484                                             hidden
# 22  76561199122907193                                             hidden
# 23  76561197992706107                                             hidden
# 24  76561198836187202  [{'appid': 242760, 'name': 'The Forest', 'hour...
# 25  76561198372618308  [{'appid': 10, 'name': 'Counter-Strike', 'hour...
# 26  76561198063386696                                             hidden
# 27  76561198998093897                                             hidden
# 28  76561198147928140  [{'appid': 10, 'name': 'Counter-Strike', 'hour...
# 29  76561199100035151                                             hidden
# 30  76561198168342632                                             hidden
# 31  76561199221735528                                             hidden
# 32  76561198129545322                                             hidden
# 33  76561199056158837                                             hidden
# 34  76561198110376063                                             hidden
# 35  76561198894416000  [{'appid': 620, 'name': 'Portal 2', 'hours': 6...
# 36  76561198134493312                                             hidden
# 37  76561199123759235                                             hidden
# 38  76561198157955203                                             hidden
# 39  76561199096168586                                             hidden
# 40  76561198797291660                                             hidden
# 41  76561198800797837                                             hidden
# 42  76561198036582543                                             hidden
# 43  76561198332706960                                             hidden
# 44  76561198352302223                                             hidden
# 45  76561198018494613                                             hidden
# 46  76561199085518999                                             hidden
# 47  76561198330806423                                             hidden
# 48  76561199208988823  [{'appid': 4700, 'name': 'Total War: MEDIEVAL ...
# 49  76561197991952543                                             hidden
