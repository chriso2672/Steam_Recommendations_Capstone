# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests
import pickle

# customisations - ensure tables show all columns
pd.set_option("max_columns", 100)

# %%
def get_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 10 seconds...')
        time.sleep(10)
        print('Retrying.')
        return get_request(url, parameters)

# %%
url = "https://steamspy.com/api.php"
parameters = {"request": "all"}

# request 'all' from steam spy and parse into dataframe
json_data = get_request(url, parameters=parameters)
steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

# generate sorted app_list from steamspy data
app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# export disabled to keep consistency across download sessions
app_list.to_csv('app_list.csv', index=False)

# instead read from stored csv
app_list = pd.read_csv('app_list.csv')

# display first few rows
app_list.head()
# Out:
# No response, waiting 10 seconds...
# Retrying.
#    appid                       name
# 0     10             Counter-Strike
# 1     20      Team Fortress Classic
# 2     30              Day of Defeat
# 3     40         Deathmatch Classic
# 4     50  Half-Life: Opposing Force

# %%
def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data

# %%
def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=50, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %%
def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data


# # Set file parameters
# download_path = '../data/download'
# steam_app_data = 'steam_app_data.csv'
# steam_index = 'steam_index.txt'

# steam_columns = [
#     'name', 'steam_appid',
   
#     'pc_requirements',
    
   
#    'genres'
# ]


# # Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
# reset_index(download_path, steam_index)

# # Retrieve last index downloaded from file
# index = get_index(download_path, steam_index)

# # Wipe or create data file and write headers if index is 0
# prepare_data_file(download_path, steam_app_data, index, steam_columns)

# # Set end and chunksize for demonstration - remove to run through entire app list
# process_batches(
#     parser=parse_steam_request,
#     app_list=app_list,
#     download_path=download_path,
#     data_filename=steam_app_data,
#     index_filename=steam_index,
#     columns=steam_columns,
#     begin=index,
#     end=10,
#     batchsize=5
# )

# %%
def parse_steamspy_request(appid, name):
    """Parser to handle SteamSpy API data."""
    url = "https://steamspy.com/api.php"
    parameters = {"request": "appdetails", "appid": appid}
    
    json_data = get_request(url, parameters)
    return json_data

# set files and columns
download_path = '../'
steamspy_data = 'steamspy_data.csv'
steamspy_index = 'steamspy_index.txt'

steamspy_columns = [
    'appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
    'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
    'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
    'languages', 'genre', 'ccu', 'tags'
]

# reset_index(download_path, steamspy_index)
index = get_index(download_path, steamspy_index)

# Wipe data file if index is 0
prepare_data_file(download_path, steamspy_data, index, steamspy_columns)

process_batches(
    parser=parse_steamspy_request,
    app_list=app_list,
    download_path=download_path, 
    data_filename=steamspy_data,
    index_filename=steamspy_index,
    columns=steamspy_columns,
    begin=index,
    end=-1,
    batchsize=50,
    pause=0.3
)
# Out:
# Starting at index 900:
#
# Exported lines 900-949 to steamspy_data.csv. Batch 0 time: 0:01:50 (avg: 0:01:50, remaining: 0:03:39)
# Exported lines 950-999 to steamspy_data.csv. Batch 1 time: 0:00:41 (avg: 0:01:15, remaining: 0:01:15)
# Exported lines 1000-1000 to steamspy_data.csv. Batch 2 time: 0:00:02 (avg: 0:00:51, remaining: 0:00:00)
#
# Processing batches complete. 100 apps written

# %%
len(app_list)
# Out:
# 1000

# %%
app_list[:-50]
# Out:
#        appid                                     name
# 0         10                           Counter-Strike
# 1         20                    Team Fortress Classic
# 2         30                            Day of Defeat
# 3         40                       Deathmatch Classic
# 4         50                Half-Life: Opposing Force
# ..       ...                                      ...
# 945  1196590                    Resident Evil Village
# 946  1203220                       NARAKA: BLADEPOINT
# 947  1207590              Builders of Egypt: Prologue
# 948  1213210  Command & Conquer Remastered Collection
# 949  1217060                           Gunfire Reborn
#
# [950 rows x 2 columns]

# %%
pd.read_csv('../steamspy_data.csv').head(50)
# Out:
#     appid                                               name  \
# 0      10                                     Counter-Strike
# 1      20                              Team Fortress Classic
# 2      30                                      Day of Defeat
# 3      40                                 Deathmatch Classic
# 4      50                          Half-Life: Opposing Force
# 5      60                                           Ricochet
# 6      70                                          Half-Life
# 7      80                     Counter-Strike: Condition Zero
# 8     130                              Half-Life: Blue Shift
# 9     220                                        Half-Life 2
# 10    240                             Counter-Strike: Source
# 11    280                                  Half-Life: Source
# 12    300                              Day of Defeat: Source
# 13    320                            Half-Life 2: Deathmatch
# 14    340                            Half-Life 2: Lost Coast
# 15    360                       Half-Life Deathmatch: Source
# 16    380                           Half-Life 2: Episode One
# 17    400                                             Portal
# 18    420                           Half-Life 2: Episode Two
# 19    440                                    Team Fortress 2
# 20    500                                        Left 4 Dead
# 21    550                                      Left 4 Dead 2
# 22    570                                             Dota 2
# 23    620                                           Portal 2
# 24    630                                        Alien Swarm
# 25    730                   Counter-Strike: Global Offensive
# 26   1250                                      Killing Floor
# 27   1840                                   Source Filmmaker
# 28   1930                            Two Worlds Epic Edition
# 29   2100                      Dark Messiah of Might & Magic
# 30   2130                      Dark Messiah of Might & Magic
# 22                                              Valve         NaN   1350996
# 23                                              Valve         NaN    266514
# 24                                              Valve         NaN     18836
# 25                                              Valve         NaN   5314329
# 26                               Tripwire Interactive         NaN     59538
# 27                                              Valve         NaN     25856
# 28                                Topware Interactive         NaN      3612
# 29                                            Ubisoft         NaN      7100
# 30                                            Ubisoft         NaN      4769
# 31                                        id Software         NaN     10508
# 32                                 Bethesda Softworks         NaN      8322
# 33                                    Blazing Griffin         NaN      5030
# 34                                         Activision         NaN      5435
# 35                              Frontier, Aspyr (Mac)         NaN      4330
# 36                PopCap Games, Inc., Electronic Arts         NaN     63909
# 37                            Double Fine Productions         NaN     12641
# 38                                                 2K         NaN      2293
# 39                                                 2K         NaN      4647
# 40                                                 2K         NaN       281
# 41                                              Valve         NaN    735383
# 42                                     GSC Game World         NaN     24561
# 43                                               SEGA         NaN      5644
# 44                                               SEGA         NaN      6557
# 45                                               SEGA         NaN      5780
# 46  SEGA, Feral Interactive (Mac), Feral Interacti...         NaN     22201
# 47                                               SEGA         NaN     13116
# 48                       Unknown Worlds Entertainment         NaN     10343
# 49                       LucasArts, Lucasfilm, Disney         NaN     11398
#
#     negative  userscore                      owners  average_forever  \
# 0       4807          0    10,000,000 .. 20,000,000             9363
# 1        874          0      2,000,000 .. 5,000,000              852
# 2        541          0     5,000,000 .. 10,000,000              811
# 3        403          0     5,000,000 .. 10,000,000              271
# 4        638          0     5,000,000 .. 10,000,000             1919
# 5        823          0     5,000,000 .. 10,000,000              228
# 6       2344          0     5,000,000 .. 10,000,000             1241
# 7       1771          0     5,000,000 .. 10,000,000             1420
# 8        868          0    10,000,000 .. 20,000,000             1920
# 9       3490          0    10,000,000 .. 20,000,000              989
# 10      5011          0    10,000,000 .. 20,000,000             7162
# 11      2657          0      2,000,000 .. 5,000,000             2294
# 12      1532          0     5,000,000 .. 10,000,000             2445
# 13      1004          0    10,000,000 .. 20,000,000              902
# 14      1216          0    20,000,000 .. 50,000,000              794
# 15       748          0     5,000,000 .. 10,000,000             1886
# 16       861          0      2,000,000 .. 5,000,000              329
# 17      1546          0    10,000,000 .. 20,000,000              329
# 18       853          0      2,000,000 .. 5,000,000              485
# 19     51806          0   50,000,000 .. 100,000,000             8421
# 20      1470          0      2,000,000 .. 5,000,000             1195
# 21     14764          0    20,000,000 .. 50,000,000             2011
# 22    261602          0  100,000,000 .. 200,000,000            43189
# 23      3258          0      2,000,000 .. 5,000,000              973
# 24      1039          0      2,000,000 .. 5,000,000              432
# 25    715132          0   50,000,000 .. 100,000,000            28405
# 26      3161          0      2,000,000 .. 5,000,000             1400
# 27      1855          0      1,000,000 .. 2,000,000             1069
# 28      1203          0      1,000,000 .. 2,000,000              448
# 29       604          0      1,000,000 .. 2,000,000              481
# 30       355          0      1,000,000 .. 2,000,000              184
# 31       409          0      1,000,000 .. 2,000,000              146
# 32       376          0      1,000,000 .. 2,000,000              390
# 33       831          0      1,000,000 .. 2,000,000              241
# 34       414          0      2,000,000 .. 5,000,000             1276
# 35       432          0      1,000,000 .. 2,000,000              537
# 36      2097          0      2,000,000 .. 5,000,000             1105
# 37       628          0      2,000,000 .. 5,000,000              361
# 38       178          0      1,000,000 .. 2,000,000              256
# 39       575          0      1,000,000 .. 2,000,000             1306
# 40        28          0      1,000,000 .. 2,000,000              163
# 41     25932          0    20,000,000 .. 50,000,000            10605
# 42      1085          0      1,000,000 .. 2,000,000              685
# 43       385          0      2,000,000 .. 5,000,000             1255
# 44       330          0      1,000,000 .. 2,000,000              423
# 45       204          0      1,000,000 .. 2,000,000             2072
# 46       969          0      1,000,000 .. 2,000,000             2070
# 47       779          0      1,000,000 .. 2,000,000             1649
# 48      1779          0      1,000,000 .. 2,000,000              976
# 49       535          0      1,000,000 .. 2,000,000              234
#
#     average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 0              426             262            323    199           999
# 1                3              27              3     99           499
# 2                0              16              0     99           499
# 3                0              12              0     99           499
# 4                3             171              5     99           499
# 5                0               3              0     99           499
# 6               58             156             60    199           999
# 7                1              32              1    199           999
# 8               71             121             71     99           499
# 9              387             380            387    199           999
# 10            1166             444           1152    199           999
# 11              27             145             27    199           999
# 12               0             154              0    199           999
# 13               0              42              0     99           499
# 14               0              24              0      0             0
# 15              11              20             11    199           999
# 16              84             186            168    159           799
# 17             104             197            119    199           999
# 18             158             279            158    159           799
# 19             896             393            268      0             0
# 20              34             197             42    199           999
# 21             166             533             83    199           999
# 22            1726            1220            894      0             0
# 23              96             555            147     79           199
# 24               0             109              0      0             0
# 25             848            6913            310      0             0
# 26              85             339            100    499          1999
# 27               0              62              0      0             0
# 28               0             408              0    249           999
# 29              25             222             25    249           999
# 30               0             177              0    249           999
# 31               0              53              0    199           499
# 32              31             116             31    399           999
# 33               0             173              0    249           999
# 34               0             516              0   1499          1999
# 35               0             149              0      0             0
# 36             274             577            410    199           499
# 37               0             180              0    499           999
# 38               0              67              0    749          2999
# 39               0             136              0    124           499
# 40               0             245              0    499           499
# 41             621            1455            135    669           999
# 42               0             326              0    599          1999
# 43               0              95              0    399          1999
# 44               0             188              0    324          1299
# 45               0             727              0    324          1299
# 46               0             339              0    624          2499
# 47               0             514              0      0             0
# 48               0             258              0    249           999
# 49               0             154              0    349           999
#
#     discount                                          languages  \
# 0         80  English, French, German, Italian, Spanish - Sp...
# 1         80  English, French, German, Italian, Spanish - Sp...
# 2         80  English, French, German, Italian, Spanish - Spain
# 3         80  English, French, German, Italian, Spanish - Sp...
# 4         80                    English, French, German, Korean
# 5         80  English, French, German, Italian, Spanish - Sp...
# 6         80  English, French, German, Italian, Spanish - Sp...
# 7         80  English, French, German, Italian, Spanish - Sp...
# 8         80                            English, French, German
# 9         80  English, French, German, Italian, Korean, Span...
# 10        80  English, French, German, Italian, Japanese, Ko...
# 11        80  English, French, German, Italian, Japanese, Sp...
# 12        80                                            English
# 13        80                                            English
# 14         0  English, French, German, Italian, Spanish - Sp...
# 15        80                                            English
# 16        80  English, French, German, Italian, Korean, Span...
# 17        80  English, French, German, Russian, Danish, Dutc...
# 18        80  English, French, German, Russian, Danish, Dutc...
# 19         0  English, Danish, Dutch, Finnish, French, Germa...
# 20        80  English, French, German, Spanish - Spain, Russ...
# 21        80  English, Danish, Dutch, Finnish, French, Germa...
# 22         0  English, Bulgarian, Czech, Danish, Dutch, Finn...
# 23        60  English, French, German, Spanish - Spain, Czec...
# 24         0                                            English
# 25         0  English, Czech, Danish, Dutch, Finnish, French...
# 26        75  English, French, Italian, German, Spanish - Sp...
# 27         0                                            English
# 28        75  English, French, German, Italian, Spanish - Sp...
# 29        75  English, French, German, Italian, Spanish - Spain
# 30        75  English, French, German, Italian, Spanish - Spain
# 31        60  English, French, Italian, German, Spanish - Spain
# 32        60  English, French, Italian, German, Spanish - Sp...
# 33        75  English, French, German, Italian, Spanish - Sp...
# 34        25  English, French, German, Italian, Spanish - Spain
# 35         0  English, French, Italian, German, Spanish - Sp...
# 36        60                                            English
# 37        50                            English, French, German
# 38        75  English, French, German, Italian, Spanish - Spain
# 39        75                                            English
# 40         0  English, French, German, Italian, Spanish - Spain
# 41        33  English, French, Italian, German, Spanish - Sp...
# 42        70  English, French, Italian, Spanish - Spain, Ger...
# 43        80  English, French, Spanish - Spain, Italian, Ger...
# 44        75  English, French, German, Italian, Spanish - Spain
# 45        75  English, French, German, Italian, Spanish - Spain
# 46        75  English, French, Italian, German, Spanish - Sp...
# 47         0                                            English
# 48        75  English, French, German, Spanish - Spain, Poli...
# 49        65  English, French, German, Italian, Spanish - Spain
#
#                                      genre     ccu  \
# 0                                   Action   11955
# 1                                   Action      94
# 2                                   Action     119
# 3                                   Action      10
# 4                                   Action     122
# 5                                   Action       8
# 6                                   Action     894
# 7                                   Action     488
# 8                                   Action      55
# 9                                   Action    1041
# 10                                  Action    4378
# 11                                  Action      69
# 12                                  Action     561
# 13                                  Action     227
# 14                                  Action      26
# 15                                  Action      11
# 16                                  Action     145
# 17                                  Action     937
# 18                                  Action     164
# 19                    Action, Free to Play  111421
# 20                                  Action     691
# 21                                  Action   20622
# 22          Action, Free to Play, Strategy  596090
# 23                       Action, Adventure    3086
# 24                                  Action      71
# 25                    Action, Free to Play  727567
# 26                                  Action     344
# 27  Animation & Modeling, Video Production    1231
# 28                                     RPG      69
# 29                             Action, RPG      67
# 30                             Action, RPG       0
# 31                                  Action      81
# 32                                  Action     229
# 33                      Action, Indie, RPG       6
# 34                                  Action     260
# 35                    Simulation, Strategy      67
# 36                                Strategy    4342
# 37                                  Action     154
# 38                                Strategy     681
# 39                                Strategy    1423
# 40                                Strategy     197
# 41                       Indie, Simulation   30761
# 42                             Action, RPG     482
# 43                        Action, Strategy     148
# 44                                Strategy     125
# 45                                Strategy     303
# 46                                Strategy    3849
# 47                                Strategy    1117
# 48                 Action, Indie, Strategy     189
# 49                                  Action      80
#
#                                                  tags
# 0   {'Action': 5372, 'FPS': 4796, 'Multiplayer': 3...
# 1   {'Action': 745, 'FPS': 306, 'Multiplayer': 258...
# 2   {'FPS': 785, 'World War II': 246, 'Multiplayer...
# 3   {'Action': 628, 'FPS': 138, 'Classic': 106, 'M...
# 4   {'FPS': 879, 'Action': 321, 'Classic': 250, 'S...
# 5   {'Action': 585, 'FPS': 128, 'Multiplayer': 103...
# 6   {'FPS': 2214, 'Sci-fi': 1749, 'Action': 1746, ...
# 7   {'Action': 1356, 'FPS': 1010, 'Shooter': 745, ...
# 8   {'FPS': 454, 'Action': 281, 'Sci-fi': 211, 'Si...
# 9   {'FPS': 3844, 'Action': 2731, 'Sci-fi': 2378, ...
# 10  {'Shooter': 5227, 'Action': 3136, 'FPS': 3099,...
# 11  {'FPS': 375, 'Action': 282, 'Classic': 222, 'S...
# 12  {'FPS': 618, 'World War II': 470, 'Multiplayer...
# 13  {'Action': 863, 'FPS': 478, 'Multiplayer': 402...
# 14  {'FPS': 1016, 'Action': 355, 'Singleplayer': 3...
# 15  {'Action': 240, 'FPS': 156, 'Multiplayer': 120...
# 16  {'FPS': 710, 'Action': 508, 'Sci-fi': 447, 'Si...
# 17  {'Puzzle': 3942, 'Puzzle-Platformer': 2984, '3...
# 18  {'FPS': 889, 'Action': 655, 'Sci-fi': 545, 'Si...
# 19  {'Free to Play': 61201, 'Hero Shooter': 60438,...
# 20  {'Zombies': 2020, 'Co-op': 1265, 'Multiplayer'...
# 21  {'Zombies': 20249, 'Co-op': 10595, 'FPS': 9450...
# 22  {'Free to Play': 58104, 'MOBA': 19289, 'Multip...
# 23  {'Platformer': 7045, 'Puzzle': 6612, 'Dark Hum...
# 24  {'Free to Play': 3682, 'Co-op': 754, 'Action':...
# 25  {'FPS': 87064, 'Shooter': 62460, 'Multiplayer'...
# 26  {'FPS': 1618, 'Zombies': 1593, 'Co-op': 1482, ...
# 27  {'Animation & Modeling': 668, 'Video Productio...
# 28  {'RPG': 716, 'Open World': 132, 'Fantasy': 96,...
# 29  {'RPG': 485, 'First-Person': 416, 'Action': 39...
# 30  {'RPG': 446, 'First-Person': 388, 'Action': 36...
# 31  {'FPS': 421, 'Classic': 420, 'Action': 270, "1...
# 32  {'FPS': 364, 'Classic': 329, 'Action': 228, 'S...
# 33  {'Multiplayer': 378, 'Indie': 173, 'First-Pers...
# 34  {'Action': 212, 'World War II': 203, 'FPS': 19...
# 35  {'Simulation': 306, 'Management': 270, 'Sandbo...
# 36  {'Tower Defense': 1181, 'Zombies': 1031, 'Stra...
# 37  {'Platformer': 646, 'Comedy': 569, 'Adventure'...
# 38  {'Strategy': 286, 'Turn-Based Strategy': 203, ...
# 39  {'Strategy': 302, 'Turn-Based Strategy': 208, ...
# 40  {'Strategy': 94, 'Turn-Based': 45, '4X': 43, '...
# 41  {'Sandbox': 17157, 'Multiplayer': 13341, 'Funn...
# 42  {'Atmospheric': 1316, 'Post-apocalyptic': 1189...
# 43  {'Strategy': 553, 'World War II': 452, 'RTS': ...
# 44  {'Strategy': 364, 'Warhammer 40K': 298, 'RTS':...
# 45  {'Strategy': 280, 'Warhammer 40K': 256, 'RTS':...
# 46  {'Strategy': 624, 'Medieval': 462, 'Historical...
# 47  {'Strategy': 527, 'Historical': 321, 'Rome': 2...
# 48  {'Multiplayer': 623, 'Strategy': 594, 'FPS': 5...
# 49  {'Action': 396, 'FPS': 395, 'Tactical': 323, '...

# %%
def process_library_batches(parser, steamid_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=50, pause=1):
    """Process library data in batches, writing directly to file.
    
    parser : custom function to format request
    steamid_list : dataframe of steamids
    download_path : path to store data
    data_filename : filename to save library data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of steamid_list)
    batchsize : number of libraries to write in each batch (default 50)
    pause : time to wait after each api request (default 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all steamids in steamid_list
    if end == -1:
        end = len(steamid_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    libraries_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        library_data = get_library_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing library data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(library_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        libraries_written += len(library_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} libraries written'.format(libraries_written))

# %%
def get_library_data(start, stop, parser, pause):
    """Return list of library data generated from parser.
    
    parser : function to handle request
    """
    library_data = []
    
    # iterate through each row of steamid_list, confined by start and stop
    for steamid in steamid_list[start:stop]:
        print('Current index: {}'.format(index), end='\r')
        
        # retrieve library data for a row, handled by supplied parser, and append to list
        data = parser(steamid)
        library_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return library_data

# %%
def parse_steam_library(steamid):
    """Parser to handle library data."""
    url = "https://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/"
    parameters = {'include_appinfo': True, 'steamid': steamid}
    
    json_data = get_library_request(url, parameters)
    
    if json_data['response']:
        return {'steamid':steamid, 'library':[{'appid': game['appid'], 'name': game['name'], 'hours': game['playtime_forever']} for game in json_data['response']['games']]}
    else:
        return {'steamid':steamid, 'library':'hidden'}

# %%
def get_library_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(
        url,
        {
            **parameters,
            **{
                'key': '9C34DB5DC9F6FB662853AC6217BC048F',
                'format': 'json'
            }
        }
    )
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_library_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 10 seconds...')
        time.sleep(10)
        print('Retrying.')
        return get_library_request(url, parameters)

# %%
with open('steamid_list.pickle', 'rb') as handle:
   steamid_list = pickle.load(handle)

# %%
steamid_list
# Out:
# [76561198219067393,
#  76561198148157441,
#  76561198993539076,
#  76561198247182340,
#  76561198278705159,
#  76561198306000904,
#  76561199041871881,
#  76561198398210058,
#  76561198313209867,
#  76561198170079242,
#  76561199187853325,
#  76561198424457231,
#  76561199073034256,
#  76561198088650778,
#  76561198128726044,
#  76561198886682654,
#  76561198311899167,
#  76561199160819745,
#  76561199085551652,
#  76561198401257513,
#  76561199063236653,
#  76561198809874484,
#  76561199122907193,
#  76561197992706107,
#  76561198836187202,
#  76561198372618308,
#  76561198063386696,
#  76561198998093897,
#  76561198147928140,
#  76561199100035151,
#  76561198168342632,
#  76561199221735528,
#  76561198129545322,
#  76561199056158837,
#  76561198110376063,
#  76561198894416000,
#  76561198134493312,
#  76561199123759235,
#  76561198157955203,
#  76561199096168586,
#  76561198797291660,
#  76561198800797837,
#  76561198036582543,
#  76561198332706960,
#  76561198352302223,
#  76561198018494613,
#  76561199085518999,
#  76561198330806423,
#  76561199208988823,
#  76561197991952543,
#  76561198412497055,
#  76561199109832865,
#  76561198274019498,
#  76561197966033066,
#  76561198066434221,
#  76561198825767086,
#  76561198009188531,
#  76561198835761333,
#  76561198191640758,
#  76561198202388663,
#  76561198199210173,
#  76561199101640894,
#  76561198930002115,
#  76561198343127238,
#  76561198084620486,
#  76561198265106632,
#  76561198354235590,
#  76561198963392715,
#  76561198819213517,
#  76561198141309134,
#  76561198995570895,
#  76561198040187089,
#  76561197970424018,
#  76561198315012315,
#  76561198375141600,
#  76561198394179810,
#  76561198351450338,
#  76561198392639726,
#  76561198055358708,
#  76561199089746165,
#  76561199065628918,
#  76561198149435649,
#  7110915,
#  76561198185054471,
#  76561198847459603,
#  76561197964656917,
#  76561198364590362,
#  76561198182203677,
#  76561198170374431,
#  76561199064189644,
#  76561198277954253,
#  1374628481747,
#  76561199182416597,
#  76561199167769302,
#  76561198368131803,
#  76561198119684830,
#  ...]

# %%
# set files and columns
download_path = '../'
library_data = 'library_data.csv'
library_index = 'library_index.txt'
api_key = '9C34DB5DC9F6FB662853AC6217BC048F'

library_columns = [
    'steamid', 'library'
]

# reset_index(download_path, library_index)
index = get_index(download_path, library_index)

# Wipe data file if index is 0
prepare_data_file(download_path, library_data, index, library_columns)

process_library_batches(
    parser=parse_steam_library,
    steamid_list=steamid_list,
    download_path=download_path, 
    data_filename=library_data,
    index_filename=library_index,
    columns=library_columns,
    begin=index,
    end=-1,
    batchsize=10,
    pause=.4
)
# Out:
# Starting at index 80:
#
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-25a5fea59f10> in <module>
#      15 prepare_data_file(download_path, library_data, index, library_columns)
#      16
# ---> 17 process_library_batches(
#      18     parser=parse_steam_library,
#      19     steamid_list=steamid_list,
#
# <ipython-input-71-aced65d8b2c0> in process_library_batches(parser, steamid_list, download_path, data_filename, index_filename, columns, begin, end, batchsize, pause)
#      38         stop = batches[i+1]
#      39
# ---> 40         library_data = get_library_data(start, stop, parser, pause)
#      41
#      42         rel_path = os.path.join(download_path, data_filename)
#
# <ipython-input-67-e14fd5a13b02> in get_library_data(start, stop, parser, pause)
#      11
#      12         # retrieve library data for a row, handled by supplied parser, and append to list
# ---> 13         data = parser(steamid)
#      14         library_data.append(data)
#      15
#
# <ipython-input-62-9a2b27e58e1e> in parse_steam_library(steamid)
#       4     parameters = {'include_appinfo': True, 'steamid': steamid}
#       5
# ----> 6     json_data = get_library_request(url, parameters)
#       7
#       8     if json_data['response']:
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      42         time.sleep(10)
#      43         print('Retrying.')
# ---> 44         return get_library_request(url, parameters)
#
# <ipython-input-63-25c17feaf0c0> in get_library_request(url, parameters)
#      40         # response is none usually means too many requests. Wait and try again
#      41         print('No response, waiting 10 seconds...')
# ---> 42         time.sleep(10)
#      43         print('Retrying.')
#      44         return get_library_request(url, parameters)
#
# KeyboardInterrupt:

# %%
pd.read_csv('../library_data.csv').head()
# Out:
#              steamid                                            library
# 0  76561198219067393  [{'appid': 220, 'name': 'Half-Life 2', 'hours'...
# 1  76561198148157441  [{'appid': 17390, 'name': 'Spore', 'hours': 26...
# 2  76561198993539076                                             hidden
# 3  76561198247182340                                             hidden
# 4  76561198278705159                                             hidden

# %%
library_df = pd.read_csv('../library_data.csv')

# %%
library_df.head(50)
# Out:
#               steamid                                            library
# 0   76561198219067393  [{'appid': 220, 'name': 'Half-Life 2', 'hours'...
# 1   76561198148157441  [{'appid': 17390, 'name': 'Spore', 'hours': 26...
# 2   76561198993539076                                             hidden
# 3   76561198247182340                                             hidden
# 4   76561198278705159                                             hidden
# 5   76561198306000904                                             hidden
# 6   76561199041871881                                             hidden
# 7   76561198398210058                                             hidden
# 8   76561198313209867                                             hidden
# 9   76561198170079242  [{'appid': 3830, 'name': 'Psychonauts', 'hours...
# 10  76561199187853325                                             hidden
# 11  76561198424457231                                             hidden
# 12  76561199073034256                                             hidden
# 13  76561198088650778  [{'appid': 4000, 'name': "Garry's Mod", 'hours...
# 14  76561198128726044                                             hidden
# 15  76561198886682654  [{'appid': 4000, 'name': "Garry's Mod", 'hours...
# 16  76561198311899167  [{'appid': 10, 'name': 'Counter-Strike', 'hour...
# 17  76561199160819745                                             hidden
# 18  76561199085551652  [{'appid': 4000, 'name': "Garry's Mod", 'hours...
# 19  76561198401257513                                             hidden
# 20  76561199063236653  [{'appid': 500, 'name': 'Left 4 Dead', 'hours'...
# 21  76561198809874484                                             hidden
# 22  76561199122907193                                             hidden
# 23  76561197992706107                                             hidden
# 24  76561198836187202  [{'appid': 242760, 'name': 'The Forest', 'hour...
# 25  76561198372618308  [{'appid': 10, 'name': 'Counter-Strike', 'hour...
# 26  76561198063386696                                             hidden
# 27  76561198998093897                                             hidden
# 28  76561198147928140  [{'appid': 10, 'name': 'Counter-Strike', 'hour...
# 29  76561199100035151                                             hidden
# 30  76561198168342632                                             hidden
# 31  76561199221735528                                             hidden
# 32  76561198129545322                                             hidden
# 33  76561199056158837                                             hidden
# 34  76561198110376063                                             hidden
# 35  76561198894416000  [{'appid': 620, 'name': 'Portal 2', 'hours': 6...
# 36  76561198134493312                                             hidden
# 37  76561199123759235                                             hidden
# 38  76561198157955203                                             hidden
# 39  76561199096168586                                             hidden
# 40  76561198797291660                                             hidden
# 41  76561198800797837                                             hidden
# 42  76561198036582543                                             hidden
# 43  76561198332706960                                             hidden
# 44  76561198352302223                                             hidden
# 45  76561198018494613                                             hidden
# 46  76561199085518999                                             hidden
# 47  76561198330806423                                             hidden
# 48  76561199208988823  [{'appid': 4700, 'name': 'Total War: MEDIEVAL ...
# 49  76561197991952543                                             hidden
